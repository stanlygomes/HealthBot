# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

def parse_xml_files(folder_path):
    qapairs = []
    for xml_root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.xml'):
                file_path = os.path.join(xml_root, file)
                print('Parsing file:', file_path)
                tree = ET.parse(file_path)
                root = tree.getroot()
                # do something with the XML data here
                for qapair in root.findall('QAPairs/QAPair'):
                    pid = qapair.attrib['pid']
                    question = qapair.find('Question').text
                    qid = qapair.find('Question').attrib['qid']
                    qtype = qapair.find('Question').attrib['qtype']
                    answer = qapair.find('Answer').text
                    qapairs.append({'pid': pid, 'question': question, 'qid': qid, 'qtype': qtype, 'answer': answer})
    df = pd.DataFrame(qapairs, columns=['pid', 'question', 'qid', 'qtype', 'answer'])
    df.to_csv('parsed_data.csv', index=False)

# %%
parse_xml_files('/content/drive/MyDrive/4090_AI_Biomedical/QA/')
# Out:
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000033.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000043.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000044.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000119.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000205.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000093.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000136.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000098.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000171.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000208.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000127.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000060.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000161.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000203.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000009.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000037.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000140.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000134.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000172.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000223.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000005.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000088.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000083.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000065.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000123.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000077.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000137.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000150.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000138.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000094.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000049.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000082.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000032.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000131.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000058.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000218.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000034.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000070.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000007.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000018.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000169.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000057.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000002.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000175.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000220.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000048.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000113.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000214.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000144.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000219.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000149.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000036.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000055.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000206.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000168.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000022.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000176.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000001.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000103.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000108.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000180.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000042.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000167.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000181.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000015.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000174.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000215.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000160.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000165.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000177.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000213.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000121.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000004.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000120.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000164.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000010.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000056.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000128.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000159.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000101.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000011.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000081.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000195.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000059.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000079.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000142.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000201.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000035.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000155.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000116.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000078.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000185.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000064.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000216.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000158.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000188.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000196.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000194.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000133.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000102.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000191.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000211.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000095.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000097.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000100.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000110.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000139.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000107.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000111.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000192.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000183.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000089.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000114.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000003.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000152.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000008.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000193.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000157.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000162.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000054.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000145.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000014.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000135.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000153.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000198.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000182.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000217.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000096.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000186.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000071.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000109.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000080.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000141.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000132.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000184.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000148.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000130.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000061.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000154.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000115.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000210.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000207.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000016.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000173.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000179.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000122.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000189.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000204.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000126.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000099.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000129.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000170.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000027.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000146.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000190.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000221.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/5_NIDDK_QA/0000013.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000206.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000978.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000917.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000632.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000207.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000652.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000451.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000673.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000656.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000167.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000349.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000638.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000092.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000498.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000217.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000331.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000274.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000581.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000213.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000537.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000039.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000661.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000009.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000891.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000324.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000665.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000443.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000072.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000681.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000313.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000520.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000102.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000774.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000687.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000546.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000169.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000458.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000375.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000806.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000861.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000647.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000050.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000388.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000329.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000117.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000521.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000418.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000131.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000047.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000752.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000727.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000132.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000688.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000959.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000801.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000549.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000263.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000769.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000534.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000007.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000423.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000841.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000491.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000654.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000623.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000926.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000452.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000629.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000195.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000123.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000812.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000422.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000966.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000613.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000517.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000285.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000771.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000700.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000645.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000234.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000583.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000442.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000934.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000852.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000002.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000415.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000348.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000749.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000455.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000503.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000225.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000739.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000013.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000020.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000182.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000074.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000495.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000793.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000864.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000518.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000032.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000378.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000928.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000080.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000449.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000529.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000789.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000969.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000448.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000660.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000856.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000371.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000145.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000563.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000662.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000208.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000776.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000004.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000502.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000624.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000912.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000051.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000480.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000363.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000585.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000428.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000253.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000426.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000594.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000352.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000267.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000258.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000612.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000037.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000578.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000952.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000836.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000052.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000214.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000736.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000444.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000232.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000199.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000810.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000372.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000212.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000773.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000116.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000276.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000717.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000737.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000524.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000970.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000620.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000597.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000368.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000077.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000671.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000515.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000655.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000012.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000686.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000658.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000979.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000400.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000122.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000484.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000325.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000877.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000750.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000298.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000043.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000606.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000817.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000608.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000762.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000712.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000018.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000788.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000332.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000165.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000914.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000837.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000707.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000059.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000493.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000099.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000586.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000272.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000508.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000697.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000202.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000693.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000738.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000392.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000797.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000028.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000850.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000198.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000826.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000091.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000781.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000377.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000625.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000290.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000129.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000157.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000058.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000395.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000413.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000682.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000709.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000055.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000120.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000743.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000566.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000699.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000574.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000779.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000350.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000957.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000963.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000764.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000393.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000622.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000278.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000690.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000472.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000138.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000481.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000940.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000294.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000506.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000950.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000461.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000830.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000175.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000785.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000872.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000501.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000657.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000849.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000722.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000275.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000483.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000244.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000235.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000559.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000192.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000364.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000676.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000103.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000617.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000286.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000269.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000466.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000436.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000598.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000603.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000714.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000462.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000237.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000101.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000488.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000719.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000236.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000255.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000542.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000651.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000357.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000370.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000886.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000431.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000010.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000485.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000910.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000626.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000740.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000916.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000539.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000017.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000833.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000615.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000369.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000777.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000961.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000439.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000775.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000096.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000870.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000470.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000083.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000706.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000430.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000154.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000845.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000824.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000075.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000933.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000570.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000259.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000454.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000104.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000155.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000981.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000766.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000735.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000040.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000859.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000432.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000487.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000666.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000351.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000772.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000025.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000702.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000650.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000795.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000751.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000006.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000066.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000976.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000867.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000803.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000962.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000531.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000108.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000190.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000440.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000188.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000139.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000339.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000374.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000564.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000723.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000211.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000927.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000829.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000672.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000890.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000433.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000509.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000061.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000464.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000553.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000765.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000742.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000899.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000610.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000631.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000802.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000268.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000604.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000359.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000915.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000105.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000345.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000951.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000595.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000260.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000628.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000540.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000637.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000827.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/4_MPlus_Health_Topics_QA/0000164.xml
# ...
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000059.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000005.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000071.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000063.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000057.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000036.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000067.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000027.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000008.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000052.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/7_SeniorHealth_QA/0000055.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000419.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000418.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000424.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000440.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000305.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000344.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000090.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000163.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000397.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000261.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000030.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000319.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000439.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000272.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000265.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000269.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000244.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000199.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000342.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000438.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000364.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000432.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000091.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000327.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000003.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000141.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000121.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000414.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000423.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000038.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000381.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000053.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000258.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000001.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000008.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000120.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000415.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000212.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000266.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000144.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000087.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000228.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000255.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000054.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000241.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000399.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000214.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000094.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000015.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000339.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000092.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000341.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000146.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000014.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000354.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000366.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000254.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000273.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/9_CDC_QA/0000313.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000032_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000007_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000019_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000043_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000027_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000037_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_7.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000031_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_9.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000027_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000035_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000022_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000031_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000007_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000014_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000005_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000028_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000028_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000025_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000019_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000028_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_3_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000017_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_7.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000009_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000037_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000018_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000007_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000037_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000036_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_3_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000033_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000032_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_7.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000019_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000016_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_8.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000028_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000015_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000014_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_8.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000040_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000007_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000027_5.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000041_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000009_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000025_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000032_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000034_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000026_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000004_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000019_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000007_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000028_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000032_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000020_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000006_9.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000003_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_7.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000001_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000024_10.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000021_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000036_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_3_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000030_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000010_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_2_6.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000021_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000026_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000014_3.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000036_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000027_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000005_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000039_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000026_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000023_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000013_3_1.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000037_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000019_4.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000027_2.xml
# Parsing file: /content/drive/MyDrive/4090_AI_Biomedical/QA/1_CancerGov_QA/0000014_4.xml

# %%
data = pd.read_csv('parsed_data.csv')

# %%
data
# Out:
#        pid                                           question          qid  \
# 0        1            What is (are) Diabetic Kidney Disease ?    0000033-1
# 1        2            What is (are) Diabetic Kidney Disease ?    0000033-2
# 2        3            What is (are) Diabetic Kidney Disease ?    0000033-3
# 3        6  What are the symptoms of Diabetic Kidney Disea...    0000033-6
# 4        7          How to diagnose Diabetic Kidney Disease ?    0000033-7
# ...    ...                                                ...          ...
# 11013    6       What is the outlook for Male Breast Cancer ?  0000027_2-6
# 11014    7        What are the stages of Male Breast Cancer ?  0000027_2-7
# 11015    8   What are the treatments for Male Breast Cancer ?  0000027_2-8
# 11016    1                 What is (are) Endometrial Cancer ?  0000014_4-1
# 11017    2           Who is at risk for Endometrial Cancer? ?  0000014_4-2
#
#                  qtype                                             answer
# 0          information  Diabetic kidney disease, also called diabetic ...
# 1          information  The kidneys are two bean-shaped organs, each a...
# 2          information  Diabetes is a complex group of diseases with a...
# 3             symptoms  People with diabetic kidney disease do not hav...
# 4      exams and tests  A health care provider diagnoses diabetic kidn...
# ...                ...                                                ...
# 11013          outlook  Survival for men with breast cancer is similar...
# 11014           stages  Key Points\n                    - After breast...
# 11015        treatment  Key Points\n                    - There are di...
# 11016      information  Key Points\n                    - Endometrial ...
# 11017   susceptibility  Health history and certain medicines can affec...
#
# [11018 rows x 5 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')

# Define a list of stop words to remove
stop_words = stopwords.words('english')

# Initialize a stemmer to reduce words to their base form
stemmer = PorterStemmer()

# Preprocess a piece of text
def preprocess_text(text):
    # Convert the text to lowercase
    text = text.lower()
    
    # Tokenize the text into individual words
    tokens = nltk.word_tokenize(text)
    
    # Remove stop words from the text
    # tokens = [word for word in tokens if not word in stop_words]
    
    # Stem each word in the text
    tokens = [stemmer.stem(word) for word in tokens]
    
    # Join the tokens back into a string
    text = ' '.join(tokens)
    
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('parsed_data.csv')

# Apply the preprocess_text() function to the 'question' and 'answer' columns
df['question'] = df['question'].apply(preprocess_text)
df['answer'] = df['answer'].apply(preprocess_text)

# Save the preprocessed data back to a CSV file
df.to_csv('preprocessed_data.csv', index=False)

# %%
newData = pd.read_csv('preprocessed_data.csv')

# %%
newData
# Out:
#        pid                                         question          qid  \
# 0        1           what is ( are ) diabet kidney diseas ?    0000033-1
# 1        2           what is ( are ) diabet kidney diseas ?    0000033-2
# 2        3           what is ( are ) diabet kidney diseas ?    0000033-3
# 3        6   what are the symptom of diabet kidney diseas ?    0000033-6
# 4        7            how to diagnos diabet kidney diseas ?    0000033-7
# ...    ...                                              ...          ...
# 11013    6     what is the outlook for male breast cancer ?  0000027_2-6
# 11014    7       what are the stage of male breast cancer ?  0000027_2-7
# 11015    8  what are the treatment for male breast cancer ?  0000027_2-8
# 11016    1               what is ( are ) endometri cancer ?  0000014_4-1
# 11017    2          who is at risk for endometri cancer ? ?  0000014_4-2
#
#                  qtype                                             answer
# 0          information  diabet kidney diseas , also call diabet nephro...
# 1          information  the kidney are two bean-shap organ , each abou...
# 2          information  diabet is a complex group of diseas with a var...
# 3             symptoms  peopl with diabet kidney diseas do not have sy...
# 4      exams and tests  a health care provid diagnos diabet kidney dis...
# ...                ...                                                ...
# 11013          outlook  surviv for men with breast cancer is similar t...
# 11014           stages  key point - after breast cancer ha been diagno...
# 11015        treatment  key point - there are differ type of treatment...
# 11016      information  key point - endometri cancer is a diseas in wh...
# 11017   susceptibility  health histori and certain medicin can affect ...
#
# [11018 rows x 5 columns]

# %%
import numpy as np

# %%
# Split the data into input and target sequences
input_seqs = np.array(data['question'])
target_seqs = np.array(data['answer'])

# Split the data into training, validation, and test sets
train_input = input_seqs[:8000]
train_target = target_seqs[:8000]
val_input = input_seqs[8000:9000]
val_target = target_seqs[8000:9000]
test_input = input_seqs[9000:]
test_target = target_seqs[9000:]

# %%
import pandas as pd
import json

# Load the preprocessed data into a pandas DataFrame
df = pd.read_csv('preprocessed_data.csv')

# Create a list of JSON objects in SQuAD format
squad_data = []
for i, row in df.iterrows():
    context = row['qtype']
    question = row['question']
    answer = row['answer']
    squad_data.append({
        'paragraphs': [{
            'context': context,
            'qas': [{
                'question': question,
                'id': str(i),
                'answers': [{
                    'text': answer,
                    'answer_start': context.find(answer)
                }]
            }]
        }]
    })

# Save the list of JSON objects as a JSON file
with open('squad_data.json', 'w') as f:
    json.dump({'data': squad_data}, f)

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 67.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

# Load the BERT-base tokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Load the BERT-base model for question answering
model = AutoModelForQuestionAnswering.from_pretrained('bert-base-uncased')

# Load the SQuAD-formatted training data
with open('squad_data.json', 'r', encoding='utf-8') as f:
    squad_data = json.load(f)

# Extract the paragraphs list from the SQuAD data
paragraphs = [q['context'] for p in squad_data['data'] for q in p['paragraphs']]

# Tokenize the input data
tokenized_data = tokenizer(paragraphs, padding='longest', truncation=True, max_length=512, return_tensors='pt')

# Get the input IDs, attention masks, and token type IDs from the tokenized data
input_ids = tokenized_data['input_ids']
attention_masks = tokenized_data['attention_mask']
token_type_ids = tokenized_data['token_type_ids']
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
input_ids.shape, token_type_ids.shape
# Out:
# (torch.Size([11018, 6]), torch.Size([11018, 6]))

# %%
import torch.nn as nn

# Define the loss function
loss_fn = nn.CrossEntropyLoss()

start_positions = []
end_positions = []

for data in squad_data['data']:
    for paragraph in data.get('paragraphs', []):
        for qas in paragraph.get('qas', []):
            for answer in qas.get('answers', []):
                start_positions.append(answer['answer_start'])
                end_positions.append(answer['answer_start'] + len(answer['text']))

start_positions = torch.tensor(start_positions, dtype=torch.long)
end_positions = torch.tensor(end_positions, dtype=torch.long)

# %%
start_positions, end_positions
# Out:
# (tensor([-1, -1, -1,  ..., -1, -1, -1]),
#  tensor([ 589, 1130, 1034,  ..., 7545, 1408,  804]))

# %%
# Create the input features
input_features = []
for i in range(len(input_ids)):
    input_feature = {}
    input_feature['input_ids'] = input_ids[i]
    input_feature['attention_mask'] = attention_masks[i]
    input_feature['token_type_ids'] = tokenizer.create_token_type_ids_from_sequences(input_ids[i].tolist())
    input_feature['start_positions'] = start_positions[i]
    input_feature['end_positions'] = end_positions[i]
    input_features.append(input_feature)

# %%
from torch.utils.data import DataLoader, TensorDataset
from transformers import AdamW

# Convert the input features to PyTorch tensors
input_ids = torch.stack([f['input_ids'] for f in input_features])
attention_masks = torch.stack([f['attention_mask'] for f in input_features])
start_positions = torch.tensor([f['start_positions'] for f in input_features])
end_positions = torch.tensor([f['end_positions'] for f in input_features])

# Set the token type IDs to a fixed value based on the input sequence's position in the batch
token_type_ids = torch.zeros_like(input_ids)
for i in range(input_ids.shape[0]):
    for j in range(input_ids.shape[1]):
        token_type_ids[i][j] = j

# %%
input_ids.shape, token_type_ids.shape
# Out:
# (torch.Size([11018, 6]), torch.Size([11018, 6]))

# %%
import torch
torch.cuda.init()

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# %%
# Create a TensorDataset from the input tensors
dataset = TensorDataset(input_ids, attention_masks, token_type_ids, start_positions, end_positions)

# Define the batch size
batch_size = 16

# Create a DataLoader to load the input data in batches
dataloader = DataLoader(dataset, batch_size=batch_size)

# Define the optimizer
optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)

# Set the model to training mode and move to device
model.to(device)
model.train()

# Define the number of training epochs
num_epochs = 10
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
import os
os.environ['TORCH_USE_CUDA_DSA'] = '1'
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import random
import numpy as np
import torch

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# Loop over the epochs
for epoch in range(num_epochs):
    # Loop over the batches in the dataloader
    for batch in dataloader:
        # Move the batch to device
        batch = tuple(t.to(device) for t in batch)
        input_ids, attention_masks, token_type_ids, start_positions, end_positions = batch

        # Clear the gradients
        optimizer.zero_grad()

        # Forward pass
        start_logits, end_logits = model(input_ids, attention_mask=attention_masks, token_type_ids=token_type_ids)

        # Compute the loss
        loss = loss_fn(start_logits, start_positions) + loss_fn(end_logits, end_positions)

        # Backward pass
        loss.backward()

        # Clip the gradients to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        # Update the parameters
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-69896d61c426> in <cell line: 2>()
#      11
#      12         # Forward pass
# ---> 13         start_logits, end_logits = model(input_ids, attention_mask=attention_masks, token_type_ids=token_type_ids)
#      14
#      15         # Compute the loss
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1846         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1847
# -> 1848         outputs = self.bert(
#    1849             input_ids,
#    1850             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1012
# -> 1013         embedding_output = self.embeddings(
#    1014             input_ids=input_ids,
#    1015             position_ids=position_ids,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     235             position_embeddings = self.position_embeddings(position_ids)
#     236             embeddings += position_embeddings
# --> 237         embeddings = self.LayerNorm(embeddings)
#     238         embeddings = self.dropout(embeddings)
#     239         return embeddings
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     188
#     189     def forward(self, input: Tensor) -> Tensor:
# --> 190         return F.layer_norm(
#     191             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     192
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2513             layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2514         )
# -> 2515     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2516
#    2517
#
# RuntimeError: CUDA error: device-side assert triggered
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
